# %%
# type casting

# LIST

# l=[2,"hello",[1,2,3]]
# # bool(l) 

# l1=[]
# #bool(l1) 

# #str(l)

# #tuple(l)

# l=[7,"hello",(1,2,3,4,5),7]

# set(l)

# TUPLE

# t=(1,2,3,4,5,4,3)

# bool(t)

# # t1= tuple()
# # bool(t1)

# str(t)

# list(t)

# set(t)

# SET

# se = (11,22,33,44)

# #bool(se)

# #se1 = set()
# #bool(se1)

# str(se)


# list(se)

# tuple(se)

# DICT

d = {"a" : 10 , "b" : 20 }

bool(d)

d1 = {}
bool(d1)

str(d)

list(d)

tuple(d)

set(d)

# WE CAN CONVERT AL  THE DATA TYPES TO BOOL AND STRING
# WE CANNOT CONVERT ANY DATA TYPE TO DICT 

# DICT------> VALUES(),  KEYS()

d = {"a" : 10 , "b" : 20 }

# list(d.values())

# tuple(d.values())

# set(d.values())

# ITESMS

list(d.items())

tuple(d.items())

set(d.items())

# NOTE--->

# WE CAN CONVERT LIST OF TUPLE OF (2 ELE) TO DICT

# WE CAN CONVERT TUPLE OF TUPLE OF ( 2 ELE) TO DICT

# WE CAN CONVERT SET OF TUPLE OF (2 ELE) TO DICT

l = [('a',10),('b',20)]

dict(l)

t = (('a',10),('b',20))
dict(t)

se = {('a',10),('b',20)}
dict(se)

l = ["hi","on"]
dict(l)
# Out:
# {'h': 'i', 'o': 'n'}
